# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhnoor14/ds2002-fa26/blob/main/notebooks/01-foundations/2026_09_04_%E2%80%94_Submission_Drill_and_Fix_a_Broken_Notebook_%E2%80%94_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DS2002 · Submission Drill and Fix a Broken Notebook
#
# **Lab — 2026-09-04 · Fall 2026**
#
# ---

# %% [markdown]
# ## Lab 02 — Submission Drill and Fix a Broken Notebook
#
# You have inherited a notebook that does not run. This is the most common way you will meet other people's code, so it is worth practicing deliberately.
#
# Seven cells below are broken. Five throw an error, and two return a wrong answer without complaining at all — those are the dangerous ones. Fix all seven, prove your fixes with assertions, then push through the full submit loop.
#
# **Submit in Canvas:** repository link and notebook link.

# %% [markdown]
# ### How to read an error before you fix it
#
# Python's traceback is read **bottom up**. The last line names the exception and the problem; the line above it points at your code.
#
# ```
# Traceback (most recent call last):
#   File "<stdin>", line 2, in <module>
#     print(greeting)
# NameError: name 'greeting' is not defined
# ```
#
# Four exceptions cover most of what you will hit this semester:
#
# | Exception | Usually means |
# |---|---|
# | `NameError` | The variable was never created, or the cell that created it never ran |
# | `TypeError` | You mixed types — text where a number belongs is the classic |
# | `KeyError` | That column or dictionary key does not exist. Check spelling and case |
# | `FileNotFoundError` | The path is wrong for *this* environment |
#
# For each fix below, write one sentence in the markdown cell saying what was actually wrong. "It works now" is not a diagnosis.

# %% [markdown]
# ### Bug 1 — a name that does not exist

# %%
# TODO: fix so this prints a greeting
greeting = 'hello'
print(greeting)
# Out:
# hello

# %% [markdown]
# **What was wrong:** The code was trying to print a variable that does not exist. greeting was never defined, so when we pass it to the print function, it was not recognized and caused a NameError.
# Explaination: The fix is to define the variable with a greeting string then call the print function on it.

# %% [markdown]
# ### Bug 2 — text where a number belongs
#
# This should print `30`. Note that `'10' + 20` and `'10' + '20'` fail in different ways — make sure you know which one you are looking at.

# %%
# TODO: fix so total is the number 30
total = 10 + 20
print(total)
# Out:
# 30

# %% [markdown]
# **What was wrong:** There was a type error. The code uses a string and an int together. The goal was to add the two numbers but the + operator servers different purposes for types. For a string, + concatenates strings together. For example, '10' + '20'  gives '1020'. However, + operator for ints actually computes the sum, so 10 + 20 would give 30. In the code, python expected a string to concatenate with '10' but we had an int instead. We need to use ints to compute sum. Explaination: The fix is to change '10' to an int so the both parts on the + operator match types (int) so that they total to 30.

# %% [markdown]
# ### Bug 3 — off the end of a list

# %%
items = ['burger', 'poncho', 'hat']

# TODO: print the LAST item, and do it in a way that still works
#       if someone adds a fourth item tomorrow
print(items[len(items)-1])
# Out:
# hat

# %% [markdown]
# **What was wrong:** The code tries to access an index that is not in the list. The list is of size 3. Indexes start from 0, meaning items has index 0,1 and 2. Trying to access something at index 3 causes an index out of range error because the array does not store anything at that index. Explaination: To get the last item, we can make use of the len() function which returns the length of a list. Since indexes start from 0, we need to subtract the list length by 1 to get the last index. len() - 1 gives the index of the ladt item.

# %% [markdown]
# ### Bug 4 — no error, wrong answer
#
# This is supposed to be the average. It prints a number, and the number is wrong.

# %%
nums = [2, 4, 6, 8]
average = sum(nums) / len(nums)
print('average:', average)
# Out:
# average: 5.0

# %% [markdown]
# **What was wrong:** The average is not computed correctly because the sum is being divided by 2. The average is cumputed by summing all numbers and dividing by their count. sum(nums) is 2 + 4 + 6 + 8 = 20. 20/2 is 10. We are dividing by 2 but we have 4 numbers. Explaination: the fix is to divide sum(nums) by len(nums). len(nums) returns 4, so 20/4 = 5.

# %% [markdown]
# ### Bug 5 — a table that cannot exist

# %%
import pandas as pd

df = pd.DataFrame({'item': ['a', 'b'], 'price': [1, 2]})
print(df)
# Out:
#   item  price
# 0    a      1
# 1    b      2

# %% [markdown]
# **What was wrong:** A value error was caused. "All arrays must be of the same length." The code builds a data frame. Column lengths must match in dataframes because values are mapped for creating rows. Fix Explaination: Ensure item and price have the same length. I did this by removing a value from price.

# %% [markdown]
# ### Bug 6 — the answer changes when you re-run it
#
# Run the next cell three times and watch the total move. Then fix it using what you built Wednesday: leave the source data alone and derive a new column from it. Your fix must give the same total on every run.

# %%
sales = pd.DataFrame({
    'game': ['NC State', 'Louisville'],
    'units': [1450, 1610],
})

# %%
# TODO: rewrite these two lines so re-running cannot change the answer
work = sales.copy()
work['change'] = work['units'] * 1.05
print('total units:', round(work['change'].sum(), 2))
# Out:
# total units: 3213.0

# %%
# Proof — this must print the same number three times
for _ in range(3):
    # TODO: rebuild from the raw values and print your total
    work = sales.copy()
    work['change'] = work['units'] * 1.05
    print('total units:', round(work['change'].sum(), 2))
# Out:
# total units: 3213.0
# total units: 3213.0
# total units: 3213.0

# %% [markdown]
# **What was wrong:** sales['units'] is being changed every time we multiply by 1.05 because the updated value is being stored in sales['units'] and its previous value gets overwritten. Good practice is to create a copy of the original data and use that going forward. Fix Explaination: create a copy dataframe of sales, then use a new column to store the transformed values.

# %% [markdown]
# ### Bug 7 — a path from someone else's laptop
#
# This notebook was written on a machine you do not have. Fix it with the pattern from Wednesday's studio: look for the file, and fall back to the inline sample so the notebook still runs for whoever opens it next.

# %%
import os
from io import StringIO

SAMPLE = '''game,units\nNC State,1450\nLouisville,1610\n'''

# TODO: replace this with a lookup + fallback that works anywhere
def data_dir():
    """First folder that actually exists, checked in order of likelihood."""
    candidates = [
        'data',                                # running inside the repo
        '../data',
        '/kaggle/input',                       # Kaggle attached dataset
        '/content/drive/MyDrive/ds2002/data',  # Colab with Drive mounted
        '/content',                            # Colab manual upload
    ]
    for path in candidates:
        if os.path.isdir(path):
            return path
    return '.'
path = os.path.join(data_dir(), 'gameday_orders.csv')
if os.path.exists(path):
    orders = pd.read_csv(path)
    print("Read real file")
else:
    orders = pd.read_csv(StringIO(SAMPLE))
    print("Fell back to sample data")

orders
# Out:
# Fell back to sample data
#          game  units
# 0    NC State   1450
# 1  Louisville   1610

# %% [markdown]
# **What was wrong:** The original code relied on a hardcoded filepath which led to a FileNotFoundError. Explaination: The fix searches for the file using data_dir() and falls back to reading the SAMPLE string if the file isn't found, so it runs anywhere without breaking.

# %% [markdown]
# ### Part 8 — prove the fixes
#
# Assertions are how you state what must be true. If one fails, the notebook stops and tells you which claim broke — much better than scrolling for a wrong number.
#
# **TODO:** uncomment each line and make them all pass.

# %%
assert isinstance(greeting, str) and greeting != ''
assert total == 30
assert items[-1] == 'hat'
assert average == 5
assert len(df) == 2
assert len(orders) >= 2
print('All checks passed.')
# Out:
# All checks passed.

# %% [markdown]
# ### Part 9 — the submit drill
#
# This is the part that is actually being graded on process. Do it in order.
#
# 1. **Restart the kernel and Run All.** Zero errors, top to bottom.
# 2. Download the notebook and put it in your repo under `notebooks/01-foundations/`, named `2026-09-04 — Submission Drill and Fix a Broken Notebook — Lab.ipynb`.
# 3. Commit with a message that says what you did, then push.
# 4. Confirm on github.com that the file is there and opens.
# 5. Fill in the cell below and submit both links in Canvas.
#
# **TODO:** fill in the four values and make the check pass.

# %%
import re

repo_url = 'https://github.com/prabhnoor14/ds2002-fa26'
commit_sha = '9135e13'
notebook_link = 'https://colab.research.google.com/drive/1EiSGYUdopcxX408nYIrv9sMViCJuNnnB?usp=sharing'
ran_restart_and_run_all = True   # TODO: set True after you actually do it

checks = {
    'repo URL is a github.com URL':
        repo_url.startswith('https://github.com/')
        and repo_url.count('/') >= 4,
    'commit hash looks like a hash':
        bool(re.fullmatch(r'[0-9a-f]{7,40}', commit_sha.strip())),
    'notebook link filled in':
        notebook_link.startswith('http'),
    'restarted and ran all':
        ran_restart_and_run_all is True,
}

for label, passed in checks.items():
    print('PASS' if passed else 'FAIL', '-', label)

print()
print('Ready to submit:', all(checks.values()))
# Out:
# PASS - repo URL is a github.com URL
# PASS - commit hash looks like a hash
# PASS - notebook link filled in
# PASS - restarted and ran all
#
# Ready to submit: True

# %% [markdown]
# ### Write-up
#
# Bugs 4 and 6 did not raise an error. In a few sentences: how would you catch that class of bug in a project where you do not already know the right answer? Name something concrete you could add to a notebook.

# %% [markdown]
# Reading through the code line-by-line and following the logic was what helped me find both of these bugs, especially the average calculation. Since you can't always catch silent errors just by looking, adding an assert statement is really useful for double-checking your work once you do know what the answer or starting data should be.

# %% [markdown]
# ### Stretch
#
# Write a `check_orders(df)` function that raises a clear error if the frame is missing either expected column, has zero rows, or contains a negative value in `units`. Then call it on `orders`. This is the shape of validation you will want in both projects.

# %%
# stretch
def check_orders(df):
  expected_cols = ['game', 'units']
  for col in expected_cols:
      assert col in df.columns, f"Missing required column: '{col}'"

  assert len(df) > 0, "DataFrame has zero rows"

  assert (df['units'] >= 0).all(), "Found negative values in 'units'"

check_orders(orders)
